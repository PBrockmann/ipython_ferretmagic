# %% [markdown]
# <hr>
# Patrick BROCKMANN - LSCE (Climate and Environment Sciences Laboratory)<br>
# <img align="left" width="40%" src="http://www.lsce.ipsl.fr/Css/img/banniere_LSCE_75.png" \><br><br>
# <hr>

# %% [markdown]
# # Monitoring

# %% [markdown]
# #### Load the ferret extension

# %% [markdown]
# *If not installed yet, type:
# %install_ext https://raw.github.com/PBrockmann/ipython-ferretmagic/master/ferretmagic.py*

# %%
# %load_ext ferretmagic

# %% [markdown]
# #### Build a list of files to open

# %% [markdown]
# ##### Get from http://esgf.extra.cea.fr/thredds/dodsC/WORK/p86caub/IPSLCM5A-MR/PROD/historicalGHGNOLU/

# %% [markdown]
# Use http://dods.extra.cea.fr/cgi-bin/nph-dods/work/p86caub/IPSLCM5A-MR/PROD/historicalGHGNOLU/ waiting official openning of Thredds servers

# %%
listfiles = (
#"http://esgf.extra.cea.fr/thredds/dodsC/WORK/p86caub/IPSLCM5A-MR/PROD/historicalGHGNOLU/v5.historicalGHGNOLUMR1/MONITORING/files/ATM_precip_global_ave.nc",
#"http://esgf.extra.cea.fr/thredds/dodsC/WORK/p86caub/IPSLCM5A-MR/PROD/historicalGHGNOLU/v5.historicalGHGNOLUMR2/MONITORING/files/ATM_precip_global_ave.nc",
#"http://esgf.extra.cea.fr/thredds/dodsC/WORK/p86caub/IPSLCM5A-MR/PROD/historicalGHGNOLU/v5.historicalGHGNOLUMR3/MONITORING/files/ATM_precip_global_ave.nc"
"http://dods.extra.cea.fr/cgi-bin/nph-dods/work/p86caub/IPSLCM5A-MR/PROD/historicalGHGNOLU/v5.historicalGHGNOLUMR1/MONITORING/files/ATM_precip_global_ave.nc",
"http://dods.extra.cea.fr/cgi-bin/nph-dods/work/p86caub/IPSLCM5A-MR/PROD/historicalGHGNOLU/v5.historicalGHGNOLUMR2/MONITORING/files/ATM_precip_global_ave.nc",
"http://dods.extra.cea.fr/cgi-bin/nph-dods/work/p86caub/IPSLCM5A-MR/PROD/historicalGHGNOLU/v5.historicalGHGNOLUMR3/MONITORING/files/ATM_precip_global_ave.nc"
)
print len(listfiles)
# Out:
# 3

# %%
for f in listfiles:
    print f
    # %ferret_run 'use "%s"' % f
# Out:
# http://dods.extra.cea.fr/cgi-bin/nph-dods/work/p86caub/IPSLCM5A-MR/PROD/historicalGHGNOLU/v5.historicalGHGNOLUMR1/MONITORING/files/ATM_precip_global_ave.nc
# http://dods.extra.cea.fr/cgi-bin/nph-dods/work/p86caub/IPSLCM5A-MR/PROD/historicalGHGNOLU/v5.historicalGHGNOLUMR2/MONITORING/files/ATM_precip_global_ave.nc
# http://dods.extra.cea.fr/cgi-bin/nph-dods/work/p86caub/IPSLCM5A-MR/PROD/historicalGHGNOLU/v5.historicalGHGNOLUMR3/MONITORING/files/ATM_precip_global_ave.nc

# %%
# %%ferret
# show data
# Out:
# <pre style="background-color:#ECF6CE; border-radius: 4px 4px 4px 4px; font-size: smaller">     currently SET data sets:
#     1> http://dods.extra.cea.fr/cgi-bin/nph-dods/work/p86caub/IPSLCM5A-MR/PROD/historicalGHGNOLU/v5.historicalGHGNOLUMR1/MONITORING/files/ATM_precip_global_ave.nc
#  name     title                             I         J         K         L         M         N
#  PRECIP_GLOBAL
#                                            ...       ...       ...       1:1872    ...       ...
#
#     2> http://dods.extra.cea.fr/cgi-bin/nph-dods/work/p86caub/IPSLCM5A-MR/PROD/historicalGHGNOLU/v5.historicalGHGNOLUMR2/MONITORING/files/ATM_precip_global_ave.nc
#  name     title                             I         J         K         L         M         N
#  PRECIP_GLOBAL
#                                            ...       ...       ...       1:1872    ...       ...
#
# ...

# %%
# %%ferret -s 800,400
# set text/font=arial
# ppl color 2, 0, 50, 100
# ppl color 3, 100, 50, 0
# ppl color 4, 80, 0, 80
# ppl color 6, 70, 70, 70
# plot/nolab/color/thick=3/grat=(dash,color=6) PRECIP_GLOBAL[l=@sbx:120,d=1], PRECIP_GLOBAL[l=@sbx:120,d=2], PRECIP_GLOBAL[l=@sbx:120,d=3]
# Out:
# <div class="myoutput"><img src="...
