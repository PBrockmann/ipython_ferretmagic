# %% [markdown]
# <hr>
# Patrick BROCKMANN - LSCE (Climate and Environment Sciences Laboratory)<br>
# <img align="left" width="40%" src="http://www.lsce.ipsl.fr/Css/img/banniere_LSCE_75.png" \><br><br>
# <hr>

# %% [markdown]
# # Monitoring

# %% [markdown]
# #### Load the ferret extension

# %%
# %load_ext ferretmagic

# %% [markdown]
# #### build a list of files to open

# %%
listfiles = (
"http://dods.extra.cea.fr/cgi-bin/nph-dods/work/p86caub/IPSLCM5A/PROD/rcp85GHG/v3.rcp85GHG1/MONITORING/files/ATM_precip_global_ave.nc" ,
"http://dods.extra.cea.fr/cgi-bin/nph-dods/work/p86caub/IPSLCM5A/PROD/rcp45GHG/v3.rcp45GHG1/MONITORING/files/ATM_precip_global_ave.nc"
)
print len(listfiles)
# Out:
# 2

# %%
for f in listfiles:
    print f
    # %ferret_run 'use "%s"' % f
# Out:
# http://dods.extra.cea.fr/cgi-bin/nph-dods/work/p86caub/IPSLCM5A/PROD/rcp85GHG/v3.rcp85GHG1/MONITORING/files/ATM_precip_global_ave.nc
# <pre style="background-color:#F79F81; border-radius: 4px 4px 4px 4px; font-size: smaller">yes? use "http://dods.extra.cea.fr/cgi-bin/nph-dods/work/p86caub/IPSLCM5A/PROD/rcp85GHG/v3.rcp85GHG1/MONITORING/files/ATM_precip_global_ave.nc"
# **Internet Data error NetCDF: Malformed or inaccessible DAP DDS (OPeNDAP/netCDF Error code -72)              Data set: http://dods.extra.cea.fr/cgi-bin/nph-dods/work/p86caub/IPSLCM5A/PROD/rcp85GHG/v3.rcp85GHG1/MONITORING/files/ATM_precip_global_ave.nc </pre>
# http://dods.extra.cea.fr/cgi-bin/nph-dods/work/p86caub/IPSLCM5A/PROD/rcp45GHG/v3.rcp45GHG1/MONITORING/files/ATM_precip_global_ave.nc
# <pre style="background-color:#F79F81; border-radius: 4px 4px 4px 4px; font-size: smaller">yes? use "http://dods.extra.cea.fr/cgi-bin/nph-dods/work/p86caub/IPSLCM5A/PROD/rcp45GHG/v3.rcp45GHG1/MONITORING/files/ATM_precip_global_ave.nc"
# **Internet Data error NetCDF: Malformed or inaccessible DAP DDS (OPeNDAP/netCDF Error code -72)              Data set: http://dods.extra.cea.fr/cgi-bin/nph-dods/work/p86caub/IPSLCM5A/PROD/rcp45GHG/v3.rcp45GHG1/MONITORING/files/ATM_precip_global_ave.nc </pre>

# %%
# %%ferret
# show data
# Out:
# <pre style="background-color:#ECF6CE; border-radius: 4px 4px 4px 4px; font-size: smaller">     currently SET data sets:
#     1> http://dods.extra.cea.fr/cgi-bin/nph-dods/work/p86caub/IPSLCM5A/PROD/rcp85GHG/v3.rcp85GHG1/MONITORING/files/ATM_precip_global_ave.nc
#  name     title                             I         J         K         L         M         N
#  PRECIP_GLOBAL
#                                            ...       ...       ...       1:1140    ...       ...
#
#     2> http://dods.extra.cea.fr/cgi-bin/nph-dods/work/p86caub/IPSLCM5A/PROD/rcp45GHG/v3.rcp45GHG1/MONITORING/files/ATM_precip_global_ave.nc  (default)
#  name     title                             I         J         K         L         M         N
#  PRECIP_GLOBAL
#                                            ...       ...       ...       1:1140    ...       ...
#
# </pre>

# %%
# %%ferret -s 800,400
# ppl color 2, 0, 50, 100
# ppl color 3, 100, 50, 0
# ppl color 6, 70, 70, 70
# plot/nolab/color/thick=3/grat=(dash,color=6) PRECIP_GLOBAL[l=@sbx:120,d=1], PRECIP_GLOBAL[l=@sbx:120,d=2]
# Out:
# <div class="myoutput"><img src="...
