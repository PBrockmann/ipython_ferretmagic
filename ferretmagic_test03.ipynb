# %% [markdown]
# <hr>
# Patrick BROCKMANN - LSCE (Climate and Environment Sciences Laboratory)<br>
# <img align="left" width="40%" src="http://www.lsce.ipsl.fr/Css/img/banniere_LSCE_75.png" \><br><br>
# <hr>

# %% [markdown]
# #### Load the ferret extension

# %%
# %reload_ext ferretmagic

# %% [markdown]
# #### Get data from ferret and put data from python

# %%
# %%ferret
# use coads_climatology
# shade sst[l=10] ; go land
# Out:
# <div class="myoutput"><img src="...

# %%
# %ferret_getdata sstdict=sst
# Out:
# <pre style="background-color:#F2F5A9; border-radius: 4px 4px 4px 4px; font-size: smaller">Message: sstdict is now available in python as a dictionary containing the variable's metadata and data array.</pre>

# %%
sstdict.keys()
# Out:
# ['axis_coords',
#  'axis_types',
#  'data_unit',
#  'axis_units',
#  'title',
#  'axis_names',
#  'missing_value',
#  'data']

# %%
sstdata = sstdict['data']
type(sstdata)
# Out:
# numpy.ndarray

# %%
import numpy
mask = numpy.abs(sstdata - sstdict['missing_value']) < 1.0E-5
sstdata[mask] = -10.0
sstdict['name'] = 'SSTCopy'
sstdict['title'] = 'SST with miss vals set to -10'
sstdict.keys()
# Out:
# ['axis_coords',
#  'axis_types',
#  'data_unit',
#  'axis_units',
#  'title',
#  'axis_names',
#  'missing_value',
#  'data',
#  'name']

# %%
# %ferret_putdata sstdict
# Out:
# <pre style="background-color:#F2F5A9; border-radius: 4px 4px 4px 4px; font-size: smaller">Message: sstdict is now available in ferret as SSTCopy</pre>

# %%
# %%ferret
# show data
# shade sstcopy[l=1]
# Out:
# <div class="myoutput"><img src="...
