# %% [markdown]
# <hr>
# Patrick BROCKMANN - LSCE (Climate and Environment Sciences Laboratory)<br>
# <img width="50%" src="http://www.lsce.ipsl.fr/Css/img/banniere_LSCE_75.png">
# <hr>

# %%
# %reload_ext ferretmagic

# %% [markdown]
# #### Discover %ferret_run line magic

# %%
for i in [100,500,1000]:
    # %ferret_run -a -s 400,400 'plot sin(i[i=1:%(i)s]*0.1)' % locals()
# Out:
# <pre style="background-color:#ECF6CE; border-radius: 4px 4px 4px 4px; font-size: smaller"></pre>
# <pre style="background-color:#ECF6CE; border-radius: 4px 4px 4px 4px; font-size: smaller"></pre>
# <pre style="background-color:#ECF6CE; border-radius: 4px 4px 4px 4px; font-size: smaller"></pre>

# %% [markdown]
# #### Another example

# %%
# %%ferret
# use levitus_climatology
# Out:
# <pre style="background-color:#ECF6CE; border-radius: 4px 4px 4px 4px; font-size: smaller"></pre>

# %%
for i in range(1,3):
    # %ferret_run -a -s 400,300 --pdf 'fill salt[k=%(i)s] ; go land' % locals()
# Out:
# <pre style="background-color:#ECF6CE; border-radius: 4px 4px 4px 4px; font-size: smaller"></pre>
# <pre style="background-color:#F2F5A9; border-radius: 4px 4px 4px 4px; font-size: smaller">Message: <a href="files/_ipy_ferret_fig_B0Lkms.pdf" target="_blank">_ipy_ferret_fig_B0Lkms.pdf</a> created.</pre>
# <pre style="background-color:#ECF6CE; border-radius: 4px 4px 4px 4px; font-size: smaller"></pre>
# <pre style="background-color:#F2F5A9; border-radius: 4px 4px 4px 4px; font-size: smaller">Message: <a href="files/_ipy_ferret_fig_XRkXOk.pdf" target="_blank">_ipy_ferret_fig_XRkXOk.pdf</a> created.</pre>
