# %% [markdown]
# <hr>
# Patrick BROCKMANN - LSCE (Climate and Environment Sciences Laboratory)<br>
# <img align="left" width="40%" src="http://www.lsce.ipsl.fr/Css/img/banniere_LSCE_75.png" \><br><br>
# <hr>

# %%
# %reload_ext ferretmagic

# %% [markdown]
# #### Discover %ferret_run line magic

# %%
for i in [100,500,1000]:
    # %ferret_run -s 300,300 'plot/thick=2 sin(i[i=1:%(i)s]*0.1)' % locals()
# Out:
# <div class="myoutput"><img src="..."/></div>
# <div class="myoutput"><img src="..."/></div>
# <div class="myoutput"><img src="..."/></div>

# %% [markdown]
# #### Another example

# %%
# %%ferret
# use levitus_climatology

# %%
for i in range(1,3):
    # %ferret_run -s 400,300 'fill salt[k=%(i)s] ; go land' % locals()
# Out:
# <pre style="background-color:#ECF6CE; border-radius: 4px 4px 4px 4px; font-size: smaller">! Enter_GO land
# ! Exit_GO
# </pre>
# <div class="myoutput"><img src="...
# <pre style="background-color:#ECF6CE; border-radius: 4px 4px 4px 4px; font-size: smaller">! Enter_GO land
# ! Exit_GO
# </pre>
# <div class="myoutput"><img src="...
