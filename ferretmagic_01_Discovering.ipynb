# %% [markdown]
# <hr>
# Patrick BROCKMANN - LSCE (Climate and Environment Sciences Laboratory)<br>
# <img align="left" width="40%" src="http://www.lsce.ipsl.fr/Css/img/banniere_LSCE_75.png" \><br><br>
# <hr>

# %% [markdown]
# #### First thing is to install the ferret extension

# %%
# %install_ext https://raw.github.com/PBrockmann/ipython-ferretmagic/master/ferretmagic.py
# Out:
# Installed ferretmagic.py. To use it, type:
#   %load_ext ferretmagic

# %% [markdown]
# #### then load the extension

# %%
# %load_ext ferretmagic
# Out:
# The ferretmagic extension is already loaded. To reload it, use:
#   %reload_ext ferretmagic

# %% [markdown]
# #### Now use extension magic cell (%%ferret) or magic line (%ferret_run)

# %%
# %%ferret
# use levitus_climatology
# show grid temp
# let a=12
# Out:
# <pre style="background-color:#ECF6CE; border-radius: 4px 4px 4px 4px; font-size: smaller">    GRID GMS1
#  name       axis              # pts   start                end
#  XAXLEVITR LONGITUDE          360mr   20.5E                19.5E(379.5)
#  YAXLEVITR LATITUDE           180 r   89.5S                89.5N
#  ZAXLEVITR DEPTH (m)           20 i-  0                    5000
#  normal    T
#  normal    E
#  normal    F
# </pre>

# %%
# %%ferret
# list a
# show data
# Out:
# <pre style="background-color:#ECF6CE; border-radius: 4px 4px 4px 4px; font-size: smaller">             VARIABLE : 12
#           12.00
#      currently SET data sets:
#     1> /opt/fer_dsets/data/levitus_climatology.cdf  (default)
#  name     title                             I         J         K         L         M         N
#  TEMP     TEMPERATURE                      1:360     1:180     1:20      ...       ...       ...
#  SALT     SALINITY                         1:360     1:180     1:20      ...       ...       ...
#
# </pre>

# %% [markdown]
# #### Usage and urrent options

# %% [markdown]
# * Control size of plot with option --size, -s width, heigh
# * Create a local pdf at the same time with option --pdf, -p
# * Do not display stdout with option --quiet, -q
#
# Discover usage by typing
# %ferret_run?

# %% [markdown]
# #### Plot are imbedded into directly into the notebook

# %%
# %%ferret -b -q -s 800,600
# shade temp[k=@std]
# go land
# Out:
# <div class="myoutput"><img src="...

# %% [markdown]
# #### You can execute ferret commands from python with the line magic %ferret_run

# %%
for i in range(1,10,2):
    # %ferret_run -q -s 300,300 'shade temp[k=%(i)s] ; go land' % locals()
# Out:
# <div class="myoutput"><img src="...
# <div class="myoutput"><img src="...
# <div class="myoutput"><img src="...
# <div class="myoutput"><img src="...
# <div class="myoutput"><img src="...

# %%
for i in [100,500,1000]:
    # %ferret_run -b -s 300,300 'plot sin(i[i=1:%(i)s]*0.1)' % locals()
# Out:
# <div class="myoutput"><img src="..."/></div>
# <div class="myoutput"><img src="..."/></div>
# <div class="myoutput"><img src="..."/></div>

# %% [markdown]
# #### Display helps

# %%
# %%ferret?

# %%
# %ferret_run?

# %%
# %%ferret
# show symb
# Out:
# <pre style="background-color:#ECF6CE; border-radius: 4px 4px 4px 4px; font-size: smaller">PPL$XPIXEL = "1010"
# PPL$YPIXEL = "818"
# BYTEORDER = "LITTLE"
# FERRET_VERSION = "6.93"
# FERRET_PLATFORM = "Linux 3.13.0-39-generic"
# FERRET_PRECISION = "double"
# NETCDF_VERSION = "4.3.1.1 of Mar 10 2014 16:33:34 $"
# FERRET_MEMORY = "50"
# SESSION_DATE = "14-Nov-14"
# SESSION_TIME = "11:10"
# SESSION_PID = "10234"
# DELTA_CPU = "63.8326"
# CLOCK_SECS = "6987.85"
# CURRENT_DATE = "14-Nov-14"
# CURRENT_TIME = "13:06:42"
# N_OPEN_DSETS = "1"
# PROGRAM_NAME = "PyFerret"
# WIN_TITLE = "14-Nov-14:11:10"
# PPL$FORMAT = "(3F10.2)"
# PPL$PLTNME = "ferret.png"
# PPL$TEKNME = "/dev/tty"
# PPL$XLEN = "8.330"
# PPL$YLEN = "5.724"
# PPL$XORG = "1.200"
# PPL$YORG = "1.400"
# PPL$WIDTH = "10.53"
# PPL$HEIGHT = "8.524"
# PPL$LINE_COUNT = " 1"
# PPL$XFACT1 = "1.000"
# PPL$XOFF1 = "0.000"
# PPL$YFACT1 = "1.000"
# PPL$YOFF1 = "0.000"
# PPL$VIEW_X = "0.000"
# PPL$VIEW_Y = "0.000"
# PPL$VIEW_Z = "0.000"
# PPL$COMMAND_FILE = "$$MEMBUF$$"
# VP_WIDTH = "10.53"
# VP_HEIGHT = "8.524"
# PPL$SCALE = "1.0000"
# VP_SCALE = "1"
# VP_RT_MARGIN = "1"
# VP_TOP_MARGIN = "1.4"
# VP_XLO = "0"
# VP_XHI = "1"
# VP_YLO = "0"
# VP_YHI = "1"
# LAB1 = "FERRET (PyFerret 1.1.0) Ver.6.93"
# LAB2 = "NOAA/PMEL TMAP"
# LAB3 = "14-NOV-2014 12:58:42"
# AX_HORIZ = "X"
# AX_VERT = "Y"
# XAXIS_REVERSED = "0"
# YAXIS_REVERSED = "0"
# PPL$XMIN = "20.50"
# PPL$XMAX = "379.5"
# LABX = "LONGITUDE"
# PPL$YMIN = "-89.50"
# PPL$YMAX = "89.50"
# LABY = "LATITUDE"
# PPL$XMIN1 = "-180.0"
# PPL$XMAX1 = "739.9"
# PPL$YMIN1 = "-85.58"
# PPL$YMAX1 = "83.65"
# XAXIS_MIN = "20.000000"
# XAXIS_MAX = "380.0000"
# YAXIS_MIN = "-90.000000"
# YAXIS_MAX = "90.00000"
# PPL$XFIRST1 = "-180.0"
# PPL$YFIRST1 = "-83.83"
# LABTIT = "TEMPERATURE (DEG C)"
# LAB4 = "DEPTH (m) : 0 to 5000 (standard deviation)"
# LABNUM_Z = "4"
# LAB5 = "DATA SET: levitus_climatology"
# LABNUM_DSET = "5"
# LAB6 = ""
# LABNUM_DATITL = "6"
# LEV_MIN = "0"
# LEV_MAX = "12"
# LEV_NUM = "24"
# LEV_DEL = "0.5"
# GO_FILE = "/opt/pyferret-1.1.0/go/land.jnl"
# LAST_GO_FILE = "/opt/pyferret-1.1.0/go/land.jnl"
# PPL$XLAST1 = "360.0"
# PPL$YLAST1 = "0.000"
# XMOUSE = "-29.42875"
# YMOUSE = "-136.6245"
# WMOUSE = "1"
# </pre>
