# %% [markdown]
# <hr>
# Patrick BROCKMANN - LSCE (Climate and Environment Sciences Laboratory)<br>
# <img align="left" width="40%" src="http://www.lsce.ipsl.fr/Css/img/banniere_LSCE_75.png" \><br><br>
# <hr>

# %% [markdown]
# #### Load the ferret extension

# %%
# %load_ext ferretmagic
# Out:
# The ferretmagic extension is already loaded. To reload it, use:
#   %reload_ext ferretmagic

# %% [markdown]
# #### Put data from python

# %%
import numpy as np
b = {}
b['name']='myvar'                         
x=np.linspace(-np.pi*4, np.pi*4, 500)
b['data']=np.sin(x)/x
b.keys()
# Out:
# ['data', 'name']

# %%
# %ferret_putdata --axis_pos (1,0,2,3,4,5) b
# Out:
# <pre style="background-color:#F2F5A9; border-radius: 4px 4px 4px 4px; font-size: smaller">Message: b is now available in ferret as myvar</pre>

# %%
# %%ferret -a
# use levitus_climatology    ! A dataset must have been opened before putting data to ferret
# show grid myvar
# ppl color 2, 0, 50, 100
# ppl color 3, 100, 50, 0
# plot/thick=3/color myvar, myvar[y=@shf:50]
# Out:
# <pre style="background-color:#ECF6CE; border-radius: 4px 4px 4px 4px; font-size: smaller">    GRID YABSTRACT
#  name       axis              # pts   start                end
#  normal    X
#  ABSTRACT  Y             99999999 r   1                    1.E+08
#  normal    Z
#  normal    T
#  normal    E
#  normal    F
# </pre>
# <div class="myoutput"><img src="...
