# %% [markdown]
# <hr>
# Patrick BROCKMANN - LSCE (Climate and Environment Sciences Laboratory)<br>
# <img align="left" width="40%" src="http://www.lsce.ipsl.fr/Css/img/banniere_LSCE_75.png" \><br><br>
# <hr>

# %% [markdown]
# Updated: 2018/01/18

# %% [markdown]
# #### Install the ferret extension

# %% [markdown]
# ferretmagic extension is now a package you can install from pip
#
# `pip install ferretmagic`
#
# https://pypi.python.org/pypi/ferretmagic

# %% [markdown]
# #### then load the extension

# %%
# %load_ext ferretmagic

# %% [markdown]
# #### Now use extension magic cell (%%ferret) or magic line (%ferret_run)

# %%
# %%ferret
# use levitus_climatology
# show grid temp
# let a=12
# Out:
# <pre style="background-color:#ECF6CE; border-radius: 4px 4px 4px 4px; font-size: smaller">    GRID GMS1
#  name       axis              # pts   start                end                 subset
#  XAXLEVITR LONGITUDE          360mr   20.5E                19.5E(379.5)        full
#  YAXLEVITR LATITUDE           180 r   89.5S                89.5N               full
#  ZAXLEVITR DEPTH (m)           20 i-  0                    5000                full
#  normal    T
# </pre>

# %%
# %%ferret
# list a
# show data
# plot i[i=1:10]
# Out:
# <pre style="background-color:#ECF6CE; border-radius: 4px 4px 4px 4px; font-size: smaller">             VARIABLE : 12
#           12.00
#      currently SET data sets:
#     1> /opt/fer_dsets/data/levitus_climatology.cdf  (default)
#  name     title                             I         J         K         L
#  TEMP     TEMPERATURE                      1:360     1:180     1:20      ...
#  SALT     SALINITY                         1:360     1:180     1:20      ...
#
# </pre>
# <div class="myoutput"><img src="...

# %% [markdown]
# #### Usage and current options

# %% [markdown]
# * Control size of plot with option --size, -s width, heigh
# * Create a local pdf at the same time with option --pdf, -p
# * Do not display stdout with option --quiet, -q
#
# Discover usage by typing
# %ferret_run?

# %% [markdown]
# #### Plot are imbedded into directly into the notebook

# %%
# %%ferret -b -q -s 800,600
# set text/font=arial
# shade temp[k=@std]
# go land
# go text_put 50 50 "aaaa"  0 2
# Out:
# <div class="myoutput"><img src="...

# %% [markdown]
# #### You can execute ferret commands from python with the line magic %ferret_run

# %%
for i in range(1,10,2):
    # %ferret_run -q -s 300,300 'shade temp[k=%(i)s] ; go land' % locals()
# Out:
# <div class="myoutput"><img src="...
# <div class="myoutput"><img src="...
# <div class="myoutput"><img src="...
# <div class="myoutput"><img src="...
# <div class="myoutput"><img src="...

# %%
for i in [100,500,1000]:
    # %ferret_run -b -s 300,300 'plot sin(i[i=1:%(i)s]*0.1)' % locals()
# Out:
# <div class="myoutput"><img src="..."/></div>
# <div class="myoutput"><img src="..."/></div>
# <div class="myoutput"><img src="..."/></div>

# %% [markdown]
# #### Display helps

# %%
# %%ferret?

# %%
# %ferret_run?

# %%
# %%ferret
# show symb
# Out:
# <pre style="background-color:#ECF6CE; border-radius: 4px 4px 4px 4px; font-size: smaller">PPL$XPIXEL = "756"
# PPL$YPIXEL = "612"
# BYTEORDER = "LITTLE"
# FERRET_VERSION = "7.3"
# FERRET_PLATFORM = "Linux 3.10.0-693.11.1.el7.x86_64"
# FERRET_PRECISION = "double"
# NETCDF_VERSION = "4.4.1.1 of Jun 27 2017 09:17:01 $"
# FERRET_MEMORY = "50"
# SESSION_DATE = "18-Jan-18"
# SESSION_TIME = "11:20"
# SESSION_PID = "36"
# DELTA_CPU = "2.268"
# CLOCK_SECS = "25.873"
# CURRENT_DATE = "18-Jan-18"
# CURRENT_TIME = "11:21:19"
# N_OPEN_DSETS = "1"
# PROGRAM_NAME = "PyFerret"
# PEAK_MEMORY = "1555201"
# SPAWN_OK = "1"
# SPAWN_STATUS = "0"
# WIN_TITLE = "18-Jan-18:11:20"
# PPL$FORMAT = "(3F10.2)"
# PPL$PLTNME = "ferret.png"
# PPL$TEKNME = "/dev/tt"
# PPL$XLEN = "8.33000"
# PPL$YLEN = "5.72400"
# PPL$XORG = "1.20000"
# PPL$YORG = "1.40000"
# PPL$WIDTH = "10.5300"
# PPL$HEIGHT = "8.52400"
# PPL$LINE_COUNT = " 1"
# PPL$XFACT1 = "1.000000"
# PPL$XOFF1 = "0.000000"
# PPL$YFACT1 = "1.000000"
# PPL$YOFF1 = "0.000000"
# PPL$VIEW_X = "0.000"
# PPL$VIEW_Y = "0.000"
# PPL$VIEW_Z = "0.000"
# PPL$COMMAND_FILE = "$$MEMBUF$$"
# VP_WIDTH = "10.53"
# VP_HEIGHT = "8.524"
# PPL$SCALE = "1.0000"
# VP_SCALE = "1"
# VP_RT_MARGIN = "1"
# VP_TOP_MARGIN = "1.4"
# VP_XLO = "0"
# VP_XHI = "1"
# VP_YLO = "0"
# VP_YHI = "1"
# LAB1 = "PyFerret (optimized) Ver.7.3"
# LAB2 = "NOAA/PMEL TMAP"
# LAB3 = "18-JAN-2018 11:21:10"
# PPL$XMIN1 = "1.000000"
# PPL$XMAX1 = "1000.000"
# PPL$YMIN1 = "-0.9999902"
# PPL$YMAX1 = "0.9999965"
# AX_VERT = "Y"
# XAXIS_REVERSED = "0"
# LABX = "X"
# AX_HORIZ = "X"
# LABY = ""
# LABTIT = "SIN(I[I=1:1000]*0.1)"
# YAXIS_REVERSED = "0"
# PPL$XFIRST1 = "1.000000"
# PPL$YFIRST1 = "9.9833414E-02"
# PPL$XLAST1 = "500.0000"
# PPL$YLAST1 = "-0.2623748"
# XAXIS_MIN = "1.00000000"
# XAXIS_MAX = "1000.00000"
# YAXIS_MIN = "-1.000000"
# YAXIS_MAX = "1.000000"
# LAB4 = "DEPTH (m) : 200"
# LAB5 = "DATA SET: levitus_climatology"
# LEV_MIN = "-2"
# LEV_MAX = "23"
# LEV_NUM = "25"
# LEV_DEL = "1"
# GO_FILE = "n/a"
# LAST_GO_FILE = "/opt/pyferret-7.3-RHEL7-64/go/land.jnl"
# </pre>
