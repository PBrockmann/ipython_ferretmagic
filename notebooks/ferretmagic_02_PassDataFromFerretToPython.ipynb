# %% [markdown]
# <hr>
# Patrick BROCKMANN - LSCE (Climate and Environment Sciences Laboratory)<br>
# <img align="left" width="40%" src="http://www.lsce.ipsl.fr/Css/img/banniere_LSCE_75.png" \><br><br>
# <hr>

# %% [markdown]
# Updated: 2016/10/28

# %% [markdown]
# #### Load the ferret extension

# %%
# %reload_ext ferretmagic

# %% [markdown]
# #### Put data from python

# %% [markdown]
# ###### First example: 1D array

# %%
import numpy as np
b = {}
b['name']='myvar'                         
x=np.linspace(-np.pi*4, np.pi*4, 500)
b['data']=np.sin(x)/x
b.keys()
# Out:
# ['data', 'name']

# %%
# %ferret_putdata --axis_pos (0,1,2,3,4,5) b
# Out:
# <pre style="background-color:#F2F5A9; border-radius: 4px 4px 4px 4px; font-size: smaller">Message: b is now available in ferret as myvar</pre>

# %%
# %%ferret
# set text/font=arial
# use levitus_climatology    ! A dataset must have been opened before putting data to ferret
# show grid myvar
# ppl color 2, 0, 50, 100, 75
# ppl color 3, 100, 50, 0, 75
# plot/thick=3/color myvar, myvar[x=@shf:50]
# Out:
# <pre style="background-color:#ECF6CE; border-radius: 4px 4px 4px 4px; font-size: smaller">    GRID XABSTRACT
#  name       axis              # pts   start                end                 subset
#  ABSTRACT  X             99999999 r   1                    1.E+08              full
#  normal    Y
#  normal    Z
#  normal    T
#  normal    E
#  normal    F
# </pre>
# <div class="myoutput"><img src="...

# %% [markdown]
# ###### Second example: 3D array

# %% [markdown]
# Create a dummy 3D array

# %%
ndepths, nlats, nlons = (10, 73, 145)

lats = np.linspace(-np.pi / 2, np.pi / 2, nlats)
lons = np.linspace(0, 2 * np.pi, nlons)
lons, lats = np.meshgrid(lons, lats)

wave = 0.75 * (np.sin(2 * lats) ** 8) * np.cos(4 * lons)
mean = 0.5 * np.cos(2 * lats) * ((np.sin(2 * lats)) ** 2 + 2)

lats = np.rad2deg(lats)
lons = np.rad2deg(lons)
data2D = wave + mean 

depths = np.linspace(1, 1000, ndepths)
data3D = np.repeat(np.expand_dims(data2D,axis=0), ndepths, axis=0)

print data3D.shape
# Out:
# (10, 73, 145)

# %% [markdown]
# Please refer to http://ferret.pmel.noaa.gov/Ferret/documentation/pyferret/data-dictionaries/

# %%
import pyferret
data2ferret = {}
data2ferret['name']='myvar'   
data2ferret['axis_names']=('depth','lats', 'lons')
data2ferret['axis_types']=(pyferret.AXISTYPE_LEVEL, pyferret.AXISTYPE_LATITUDE, pyferret.AXISTYPE_LONGITUDE)
data2ferret['axis_units']=('meters','degrees_north','degrees_east')
data2ferret['axis_coords']=(depths[:], lats[:,0], lons[0,:])
data2ferret['data']=data3D
data2ferret.keys()
# Out:
# ['name', 'axis_names', 'axis_types', 'axis_units', 'axis_coords', 'data']

# %%
# %ferret_putdata data2ferret
# Out:
# <pre style="background-color:#F2F5A9; border-radius: 4px 4px 4px 4px; font-size: smaller">Message: data2ferret is now available in ferret as myvar</pre>

# %%
# %%ferret
# show data
# shade myvar[k=1]
# Out:
# <pre style="background-color:#ECF6CE; border-radius: 4px 4px 4px 4px; font-size: smaller">     currently SET data sets:
#     1> /opt/ferret_dsets/data/levitus_climatology.cdf  (default)
#  name     title                             I         J         K         L         M         N
#  TEMP     TEMPERATURE                      1:360     1:180     1:20      ...       ...       ...
#  SALT     SALINITY                         1:360     1:180     1:20      ...       ...       ...
#  ------ Python Variables ------
#  MYVAR    myvar                            1:145     1:73      1:10      ...       ...       ...
#
# </pre>
# <div class="myoutput"><img src="...
