# %% [markdown]
# <hr>
# Patrick BROCKMANN - LSCE (Climate and Environment Sciences Laboratory)<br>
# <img align="left" width="40%" src="http://www.lsce.ipsl.fr/Css/img/banniere_LSCE_75.png" \><br><br>
# <hr>

# %% [markdown]
# Updated: 2016/10/28

# %% [markdown]
# # Monitoring

# %% [markdown]
# #### Load the ferret extension

# %%
# %load_ext ferretmagic

# %% [markdown]
# #### Build a list of files to open

# %% [markdown]
# ##### Get from http://esgf.extra.cea.fr/thredds/catalog/work/p86caub/IPSLCM5A-MR/PROD/historicalGHGNOLU/catalog.html

# %%
listfiles = (
"http://esgf.extra.cea.fr/thredds/dodsC/work/p86caub/IPSLCM5A-MR/PROD/historicalGHGNOLU/v5.historicalGHGNOLUMR1/MONITORING/files/ATM_precip_global_ave.nc",
"http://esgf.extra.cea.fr/thredds/dodsC/work/p86caub/IPSLCM5A-MR/PROD/historicalGHGNOLU/v5.historicalGHGNOLUMR2/MONITORING/files/ATM_precip_global_ave.nc",
"http://esgf.extra.cea.fr/thredds/dodsC/work/p86caub/IPSLCM5A-MR/PROD/historicalGHGNOLU/v5.historicalGHGNOLUMR3/MONITORING/files/ATM_precip_global_ave.nc"
)
print len(listfiles)
# Out:
# 3

# %%
for f in listfiles:
    print f
    # %ferret_run 'use "%s"' % f
# Out:
# http://esgf.extra.cea.fr/thredds/dodsC/work/p86caub/IPSLCM5A-MR/PROD/historicalGHGNOLU/v5.historicalGHGNOLUMR1/MONITORING/files/ATM_precip_global_ave.nc
# http://esgf.extra.cea.fr/thredds/dodsC/work/p86caub/IPSLCM5A-MR/PROD/historicalGHGNOLU/v5.historicalGHGNOLUMR2/MONITORING/files/ATM_precip_global_ave.nc
# http://esgf.extra.cea.fr/thredds/dodsC/work/p86caub/IPSLCM5A-MR/PROD/historicalGHGNOLU/v5.historicalGHGNOLUMR3/MONITORING/files/ATM_precip_global_ave.nc

# %%
# %%ferret
# show data
# Out:
# <pre style="background-color:#ECF6CE; border-radius: 4px 4px 4px 4px; font-size: smaller">     currently SET data sets:
#     1> http://esgf.extra.cea.fr/thredds/dodsC/work/p86caub/IPSLCM5A-MR/PROD/historicalGHGNOLU/v5.historicalGHGNOLUMR1/MONITORING/files/ATM_precip_global_ave.nc
#  name     title                             I         J         K         L         M         N
#  PRECIP_GLOBAL
#                                            ...       ...       ...       1:1872    ...       ...
#
#     2> http://esgf.extra.cea.fr/thredds/dodsC/work/p86caub/IPSLCM5A-MR/PROD/historicalGHGNOLU/v5.historicalGHGNOLUMR2/MONITORING/files/ATM_precip_global_ave.nc
#  name     title                             I         J         K         L         M         N
#  PRECIP_GLOBAL
#                                            ...       ...       ...       1:1872    ...       ...
#
# ...

# %%
# %%ferret -s 800,400
#
# cancel mode logo
# set text/font=arial
#
# ppl color 2, 0, 50, 100, 50
# ppl color 3, 100, 50, 0, 50
# ppl color 4, 80, 0, 80, 50
# ppl color 6, 70, 70, 70
#
# let/title="GHGNOLUMR1" var1 = PRECIP_GLOBAL[l=@sbx:120,d=1]
# let/title="GHGNOLUMR2" var2 = PRECIP_GLOBAL[l=@sbx:120,d=2]
# let/title="GHGNOLUMR3" var3 = PRECIP_GLOBAL[l=@sbx:120,d=3]
#
# plot/color/thick=3/grat=(dash,color=6)/key=title var1, var2, var3
# Out:
# <div class="myoutput"><img src="...
